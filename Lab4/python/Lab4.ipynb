# %% [markdown]
# # Digital Signal Processing
#
# ### MsCV - ViBOT - MAIA

# %% [markdown]
# The reasons to convert signals into frequency domain is to get the idea of different frequency components it is composed of. This might help to detect the required signals and classify them, for examples, speak or speech recognition from a sound wave, noise removal from the image, or finding recurring patterns within images.

# %%
# %matplotlib inline
# %pprint off

# To make some nice plot
import matplotlib.pyplot as plt
# To play with arrays
import numpy as np
from skimage import io
from skimage import img_as_float
from matplotlib import cm
from scipy.stats import norm
from scipy import signal
# Out:
# Pretty printing has been turned OFF

# %% [markdown]
# # Discrete Fourier Transform
# The Discrete Fourier Transform (DFT) converts discrete data from a time domain into frequency domain. The DFT analyzes the finite segment in one period of an infinitely extended periodic signal, which is defined as:
# $$ X[n] = \sum^{N-1}_{k = 0} x[k] e^{-j(2\pi/N)kn}$$
#
#
# Note: The Fast Fourier Transform (FFT) is simply an algorithm to compute the DFT in a faster way!
#
# ## Exercise 1 -  ** DFT**
# **1.1** The DFT of a $5$ Hz sin wave sampled with the sampling of $f_s = 50$ Hz over 1000 (N = 1000) samples is computed as follows:

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# time vector for one second
t = np.arange(0, 1., 1./fs)
# sin wave 
x_n = np.sin(2*np.pi*f*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('Sin wave Signal')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()
# Out:
# /home/masters/anaconda2/lib/python2.7/site-packages/numpy/core/numeric.py:474: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# **1.2** Compute the DFT of a cosine wave, how that differs from that of a sine wave ?

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# time vector for one second
t = np.arange(0, 1., 1./fs)
# cos wave 
x_n = np.cos(2*np.pi*f*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))

plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('Cos wave Signal')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()

# %% [markdown]
# **1.3** Use square wave using the same frequncy and sampling frequency.
#
# Note use `signal.square` to create your signal.

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# time vector for one second
t = np.arange(0, 1., 1./fs)
# square wave 
x_n = signal.square(2*np.pi*f*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))

plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('Square wave Signal')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()

# %% [markdown]
# **1.4** Use white Gaussian noise N = 10000.
#
# (Note use `np.random.normal` to create your noise)

# %%
# Signal frequency and sampling frequency
mu = 0.0
sigma = 1.0
N = 10000
g = np.random.normal(mu, sigma, (N, ))

plt.figure()
plt.plot(g)
plt.title('Noise signal')
plt.show()

n, bins, patches = plt.hist(g, 50, normed=1, alpha=0.25)

distribution = norm.pdf(bins, mu, sigma)
plt.plot(bins, distribution, 'g')
plt.title('Histogram')
plt.show()

G = np.fft.fftshift(np.fft.fft(g, N))
fr = (np.arange(-N/2,N/2,1))

plt.subplot(311)
plt.plot(fr, np.abs(G))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(312)
plt.plot(fr, np.real(G))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(313)
plt.plot(fr, np.imag(G))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()

# %% [markdown]
# ## Exercise 2 -  Sampling
#
# Generate and display the following signals of 1 sec duration.
# $$x[n] = 3 cos(2\pi\frac{f_{1}}{f_{s}}n) + 4 sin(2\pi\frac{f_{2}}{f_{s}}n)$$
# for $f_{1} = 5$ Hz and $f_{2} = 20$ Hz, sampled with the sampling frequencies of $f_{s} = [10, 20, 25, 40, 50, 100, 150]$

# %% [markdown]
# **2.1** Plot $x[n]$ for different sampling frequencies in time domain.

# %%
f1 = 5.
f2 = 20.

fs = [10., 20., 25., 40., 50., 100., 150.]



for i in range(len(fs)):
    
    t = np.arange(0, 1., 1./fs[i])
    x_n = 3*np.cos(2*np.pi*(f1)*t) + 4*np.sin(2*np.pi*(f2)*t)  
    # wave signal
    plt.figure
    plt.plot(t, x_n)
    plt.title('Wave Signal with sampling frequency: ' + str(fs[i]))
    plt.xlabel('Time(sec)')
    plt.ylabel('Amplitude')
    plt.show()

# %% [markdown]
# **2.2.** Discuss the aliasing effects in the time domain:

# %% [markdown]
# **2.3** Compute the FFT of the above signals and display their centered frequency components.
# Discuss your observations.

# %%
f1 = 5.
f2 = 20.

fs = [10., 20., 25., 40., 50., 100., 150.]

N = 1000
for i in range(len(fs)):
    
    t = np.arange(0, 1., 1./fs[i])
    x_n = 3*np.cos(2*np.pi*(f1)*t) + 4*np.sin(2*np.pi*(f2)*t)    
    fr = (np.arange(-N/2,N/2,1)) * fs[i]/N
    x_f = np.fft.fftshift(np.fft.fft(x_n, N))
    plt.plot(fr, x_f)
    plt.title('Magnitude, fs: ' + str(fs[i]))
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('|X(f)|')
    plt.show()

# %% [markdown]
# ## Exercise 3 - 1D  DFT for image classification
#
# 1D DFT can be applied to analyze the frequency components along the one dimensional profile of an image. Here we want to use these information to classify the images into two different classes (**barcode** and **non-barcode** classes)
# To do so we first
# * Load the images from 1D-DFT folder
#     * **3.1** you have to normalize and resize the images to the smallest size
#     * **3.2** Take 1D profile as shown in the example and compute its DFT.
# ![](profile1.png)
#
#     * **3.3** Separate the images to two different groups of **barcode** and **non-barcode** based on their frequency spectrum of their profile
# * Some information regarding the images:
#     * There are 54 images while Images [1, 2, 6, 44:54] are barcode images and the others are similar patterns.
#
# **3.4** Discuss your results

# %%
Path = '../images/1D-DFT/'
import os, os.path
from skimage import color
from scipy import misc
from skimage import transform

sizes = []
r = 0
c=0
n = 0
filenames = sorted([f for f in os.listdir(Path)])

for f in filenames:
    Img = io.imread(os.path.join(Path,f))
    Img = img_as_float(Img)
    Img = color.rgb2grey(Img)
    

n = np.min(sizes)
for i in range (len(sizes)):
    if n == sizes[i]:
        r,c = sizes[i]

for f in filenames:
    Img = transform.resize(Img, (r,c))

# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-84958229683d> in <module>()
#      17
#      18
# ---> 19 n = np.min(sizes)
#      20 for i in range (len(sizes)):
#      21     if n == sizes[i]:
#
# /home/masters/anaconda2/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in amin(a, axis, out, keepdims)
#    2347         except AttributeError:
#    2348             return _methods._amin(a, axis=axis,
# -> 2349                                   out=out, keepdims=keepdims)
#    2350         # NOTE: Dropping the keepdims parameter
#    2351         return amin(axis=axis, out=out)
#
# /home/masters/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.pyc in _amin(a, axis, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
# ---> 29     return umr_minimum(a, axis, None, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
from skimage import transform


img = io.imread('../images/1D-DFT/tifImage_001.tif')
img = img_as_float(img)
img = transform.rescale(img, 0.6)
io.imshow(img)
